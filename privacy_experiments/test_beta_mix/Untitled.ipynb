# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
grid = np.loadtxt("out/dens_grid.csv", delimiter=",")
dens = np.loadtxt("out/eval_dens.csv", delimiter=",")
data = np.loadtxt("out/data.csv", delimiter=",")
best_clus = np.loadtxt("out/best_clus.csv", delimiter=",")
clus_chain = np.loadtxt("out/clus_chain.csv", delimiter=",")

# %%
uniq_clus = np.unique(best_clus)

for u in uniq_clus:
    wh = np.where(best_clus == u)[0]
    plt.scatter(data[wh], np.zeros_like(wh))

plt.plot(grid, np.mean(np.exp(dens), axis=0))
